# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Rappler (Rods)

# %%
df_rappler = pd.read_csv('datasets/rappler.csv')
df_rappler['published_dates'] = pd.to_datetime(df_rappler['published_dates'])
df_rappler.info()
df_rappler.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   urls              83 non-null     object
#  1   titles            83 non-null     object
#  2   authors           83 non-null     object
#  3   published_dates   83 non-null     datetime64[ns]
#  4   articles_content  83 non-null     object
#  5   news_org          83 non-null     object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 4.0+ KB
#                                                 urls  \
# 0  https://www.rappler.com/newsbreak/explainers/w...
# 1  https://www.rappler.com/newsbreak/iq/timeline-...
# 2  https://www.rappler.com/nation/philippines-rec...
# 3  https://www.rappler.com/nation/philippines-gra...
# 4  https://www.rappler.com/nation/philippines-rec...
#
#                                               titles         authors  \
# 0  Here’s why COVID-19 vaccines haven’t arrived i...  SOFIA TOMACRUZ
# 1  TIMELINE: The Philippines’ 2021 COVID-19 vacci...  SOFIA TOMACRUZ
# 2  After initial delay, Philippines to receive As...  SOFIA TOMACRUZ
# 3  Philippines grants emergency approval for Sino...  SOFIA TOMACRUZ
# 4  Philippines receives first COVID-19 vaccine de...  SOFIA TOMACRUZ
#
#       published_dates                                   articles_content  \
# 0 2021-02-18 09:22:00  MANILA, PHILIPPINES\r\nThe Philippine governme...
# 1 2021-02-04 19:43:00  MANILA, PHILIPPINES\r\n(UPDATED) On March 1, t...
# 2 2021-03-03 14:41:00  MANILA, PHILIPPINES\r\n(UPDATED) Malacañang sa...
# 3 2021-02-22 12:19:00  MANILA, PHILIPPINES\r\n(UPDATED) Its lower eff...
# 4 2021-02-28 16:16:00  MANILA, PHILIPPINES\r\n(3rd UPDATE) The arriva...
#
#   news_org
# 0  Rappler
# 1  Rappler
# 2  Rappler
# 3  Rappler
# 4  Rappler

# %% [markdown]
# ## GMA News (Rods)

# %%
df_gma = pd.read_csv('datasets/gmanews.csv')
df_gma['published_dates'] = pd.to_datetime(df_gma['published_dates'])
df_gma.info()
df_gma.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   urls              287 non-null    object
#  1   titles            287 non-null    object
#  2   authors           287 non-null    object
#  3   published_dates   287 non-null    datetime64[ns]
#  4   articles_content  287 non-null    object
#  5   news_org          287 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 13.6+ KB
#                                                 urls  \
# 0  https://www.gmanetwork.com/news/news/nation/77...
# 1  https://www.gmanetwork.com/news/news/nation/77...
# 2  https://www.gmanetwork.com/news/news/content/7...
# 3  https://www.gmanetwork.com/news/news/nation/77...
# 4  https://www.gmanetwork.com/news/news/nation/77...
#
#                                               titles            authors  \
# 0  Philippines, Indian firm in talks for at least...  JULIA MARI ORNEDO
# 1  Philippines administers first official COVID-1...  JULIA MARI ORNEDO
# 2  UNICEF chief: $1B more needed for COVAX COVID-...           GMA News
# 3  Sinovac COVID-19 vaccine might have better eff...  JULIA MARI ORNEDO
# 4  COVID-19 vaccine rollout not a reason to be co...  ANNA FELICIA BAJO
#
#       published_dates                                   articles_content  \
# 0 2021-03-10 10:32:00  The Philippines and Indian firm Bharat Biotech...
# 1 2021-03-01 09:46:00  University of the Philippines-Philippine Gener...
# 2 2021-03-10 22:03:00  DUBAI - The United Nations' children's fund on...
# 3 2021-03-02 16:48:00  The coronavirus vaccine developed by Chinese f...
# 4 2021-03-08 16:04:00  House Speaker Lord Allan Velasco on Monday sai...
#
#    news_org
# 0  GMA News
# 1  GMA News
# 2  GMA News
# 3  GMA News
# 4  GMA News

# %% [markdown]
# ## Manila Bulletin (Gee-R)

# %%
# # TODO
df_manilabulletin = pd.read_csv('datasets/manilabulletin_final.csv')
# df_manilabulletin['published_dates'] = pd.to_datetime(df_manilabulletin['published_dates'])
df_manilabulletin.info()
df_manilabulletin.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   urls              743 non-null    object
#  1   titles            743 non-null    object
#  2   authors           743 non-null    object
#  3   published_dates   743 non-null    object
#  4   articles_content  743 non-null    object
#  5   news_org          743 non-null    object
# dtypes: object(6)
# memory usage: 35.0+ KB
#                                                 urls  \
# 0  https://mb.com.ph/2021/03/10/bacoor-vaccinates...
# 1  https://mb.com.ph/2021/03/10/doh-urged-to-reco...
# 2  https://mb.com.ph/2021/03/10/covid-19-vaccines...
# 3  https://mb.com.ph/2021/03/09/pfizer-covid-19-v...
# 4  https://mb.com.ph/2021/03/09/20k-doses-of-astr...
#
#                                               titles            authors  \
# 0  Bacoor vaccinates 114 health workers in first ...   Carla Bauto Deña
# 1  DOH urged to recommend a COVID-19 vaccine fit ...  Hannah Torregoza
# 2  COVID-19 vaccines eyed for Boracay tourist wor...           Tara Yap
# 3  Pfizer COVID-19 vaccine may arrive in PH next ...  Leslie Ann Aquino
# 4  20K doses of AstraZeneca COVID-19 vaccine set ...    Calvin Cordova
#
#                                      published_dates  \
# 0  0     2021-03-10 15:51:00\n1     2021-03-10 14...
# 1  0     2021-03-10 15:51:00\n1     2021-03-10 14...
# 2  0     2021-03-10 15:51:00\n1     2021-03-10 14...
# 3  0     2021-03-10 15:51:00\n1     2021-03-10 14...
# 4  0     2021-03-10 15:51:00\n1     2021-03-10 14...
#
#                                     articles_content        news_org
# 0  BACOOR CITY, Cavite – The city government led ...  manilabulletin
# 1  A House lawmaker on Wednesday called on the De...  manilabulletin
# 2  ILOILO CITY—As vaccination against coronavirus...  manilabulletin
# 3  The Pfizer COVID-19 vaccine may soon arrive in...  manilabulletin
# 4  CEBU CITY—At least 20,000 doses of COVID-19 va...  manilabulletin

# %%
df_manilabulletin['published_dates'].nunique()
# Out:
# 1

# %% [markdown]
# ## ABS-CBN (Gee-R)

# %%
# # TODO
df_abscbn = pd.read_csv('datasets/abscbn_final.csv')
df_abscbn['published_dates'] = pd.to_datetime(df_abscbn['published_dates'])
df_abscbn.info()
df_abscbn.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   urls              327 non-null    object
#  1   titles            327 non-null    object
#  2   authors           327 non-null    object
#  3   published_dates   327 non-null    datetime64[ns]
#  4   articles_content  327 non-null    object
#  5   news_org          327 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 15.5+ KB
#                                                 urls  \
# 0  https://news.abs-cbn.com/news/03/10/21/philipp...
# 1  https://news.abs-cbn.com/news/01/14/21/philipp...
# 2  https://news.abs-cbn.com/news/03/09/21/covaxin...
# 3  https://news.abs-cbn.com/news/01/14/21/philipp...
# 4  https://news.abs-cbn.com/news/01/26/21/philipp...
#
#                                               titles  \
# 0  Philippines to get initial shipment of Pfizer ...
# 1  Philippines approves Pfizer's COVID-19 vaccine...
# 2  Covaxin maker can allocate at least 10M COVID-...
# 3  Philippines books 17 million COVID-19 vaccine ...
# 4  Philippines eyes 10 million COVID-19 vaccine d...
#
#                                              authors     published_dates  \
# 0                                       ABS-CBN News 2021-03-10 14:09:00
# 1                     Kristine Sabillo, ABS-CBN News 2021-01-14 11:48:00
# 2                                       ABS-CBN News 2021-03-09 12:22:00
# 3  Isay Reyes-Kang and Jamaine Punzalan ABS-CBN News 2021-01-14 13:55:00
# 4                     Jamaine Punzalan, ABS-CBN News 2021-01-26 17:57:00
#
#                                     articles_content news_org
# 0  A health worker holds prepared syringes with d...   abscbn
# 1  Video courtesy of the Department of Health\nMA...   abscbn
# 2  \nMANILA - The manufacturer of COVID-19 vaccin...   abscbn
# 3  A vial and syringe are seen in front of a disp...   abscbn
# 4  Vials with a sticker reading, "COVID-19 / Coro...   abscbn

# %% [markdown]
# ## Philippine Star & Manila Times (Hurly)

# %%
# # TODO
df_philstar = pd.read_csv('datasets/manila_and_philstar.csv',index_col = 0)
df_philstar['published_dates'] = pd.to_datetime(df_philstar['dates'])
df_philstar = df_philstar.drop(columns = 'dates')
df_philstar = df_philstar.rename(columns = {'news_agency':'news_org','headlines':'titles','contents':'article_contents'})
df_philstar.info()
df_philstar.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 0 to 128
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   urls              239 non-null    object
#  1   authors           239 non-null    object
#  2   titles            239 non-null    object
#  3   article_contents  239 non-null    object
#  4   news_org          239 non-null    object
#  5   published_dates   239 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 13.1+ KB
#                                                 urls                  authors  \
# 0  https://www.manilatimes.net/2021/03/11/news/re...        Asangan T. Madale
# 1  https://www.manilatimes.net/2021/03/11/busines...     Agence France-Presse
# 2  https://www.manilatimes.net/2021/03/11/news/na...  CHRISTIAN CROW MAGHANOY
# 3  https://www.manilatimes.net/2021/03/10/news/go...            Keith Calayag
# 4  https://www.manilatimes.net/2021/03/10/news/na...              Red Mendoza
#
#                                               titles  \
# 0  Frontliners first to get Covid-19 vaccine in L...
# 1                 $1.9-T Covid aid to pass Wednesday
# 2              Enforce health protocols, police told
# 3         Govt mulls 24/7 Covid-19 vaccination drive
# 4        DILG orders crackdown on protocol violators
#
#                                     article_contents      news_org  \
# 0  Lanao del Norte Gov. Imelda ‘Angging’ Quibranz...  Manila Times
# 1  WASHINGTON, D. C.: United States President Joe...  Manila Times
# 2  Philippine National Police chief Gen. Debold S...  Manila Times
# 3  THE government is considering a 24-hour vaccin...  Manila Times
# 4  The Department of the Interior and Local Gover...  Manila Times
#
#   published_dates
# 0      2021-03-11
# 1      2021-03-11
# 2      2021-03-11
# 3      2021-03-10
# 4      2021-03-10

# %%
# # TODO
# df_themanilatimes = pd.read_csv('datasets/themanilatimes.csv')
# df_themanilatimes.info()
# df_themanilatimes

# %% [markdown]
# ## Sun Star (Gee-R)

# %%
# # TODO
df_sunstar = pd.read_csv('datasets/sunstar_final.csv')
df_sunstar = df_sunstar.dropna(subset = ['articles_content'])
df_sunstar['published_dates'] = pd.to_datetime(df_sunstar['published_dates'])
df_sunstar['authors'] = df_sunstar['authors'].fillna('sunstar')
df_sunstar.info()
df_sunstar.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 0 to 707
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   urls              699 non-null    object
#  1   titles            699 non-null    object
#  2   authors           699 non-null    object
#  3   published_dates   699 non-null    datetime64[ns]
#  4   articles_content  699 non-null    object
#  5   news_org          699 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 38.2+ KB
#                                                 urls  \
# 0  https://www.sunstar.com.ph/article/1875784/Bac...
# 1  https://www.sunstar.com.ph/article/1885323/Bac...
# 2  https://www.sunstar.com.ph/article/1881246/Bac...
# 3  https://www.sunstar.com.ph/article/1885234/Bac...
# 4  https://www.sunstar.com.ph/article/1884194/Bac...
#
#                                               titles              authors  \
# 0  'Bacolod to be prioritized' once Covid-19 vacc...  MERLINDA A. PEDROSA
# 1     Bacolod to use 26 Covid-19 vaccination centers  MERLINDA A. PEDROSA
# 2         Bacolod forms Covid-19 vaccination council  MERLINDA A. PEDROSA
# 3  Bacolod mayor says Covid-19 vaccine will possi...  MERLINDA A. PEDROSA
# 4   Bacolod to participate in Covid-19 vaccine trial  MERLINDA A. PEDROSA
#
#   published_dates                                   articles_content news_org
# 0      2020-11-04  BACOLOD City will be one of the top local gove...  sunstar
# 1      2021-02-08  THE City Government of Bacolod already identif...  sunstar
# 2      2020-12-28  BACOLOD City Mayor Evelio Leonardia has issued...  sunstar
# 3      2021-02-07  “OUR vaccines will come possibly in July, but ...  sunstar
# 4      2021-01-28  THE Emergency Operations Center (EOC) in Bacol...  sunstar

# %% [markdown]
# ## Inquirer (Andrei)

# %%
# # TODO
# df_inquirer = pd.read_csv('datasets/inquirer.csv')
# df_inquirer.info()
# df_inquirer

# %% [markdown]
# ## CNN (Justine)

# %%
# # TODO
df_cnn = pd.read_csv('datasets/CNN Scraped Articles.csv',index_col = 0)
df_cnn['published_dates'] = pd.to_datetime(df_cnn['published_date'])
df_cnn = df_cnn.drop(columns = 'published_date', axis = 1)
df_cnn.head()
# Out:
#                                                 urls  \
# 0  http://cnnphilippines.com/news/2020/8/15/Discu...
# 1  http://cnnphilippines.com/world/2020/11/17/cov...
# 2  http://cnnphilippines.com/news/2020/12/6/duque...
# 3  http://cnnphilippines.com/world/2020/12/22/Cov...
# 4  http://cnnphilippines.com/world/2021/2/25/ghan...
#
#                                               titles  \
# 0  Discussions with other COVID vaccine manufactu...
# 1  Good news on the vaccine front shows 'light at...
# 2  Duque willing to take first dose of COVID-19 v...
# 3  Vatican OKs getting Covid-19 vaccines that use...
# 4  Ghana becomes first country to receive Covid v...
#
#                             authors  \
# 0                    Paolo Barcelon
# 1                         Holly Yan
# 2             CNN Philippines Staff
# 3                        John Allen
# 4  Stephanie Busari and Eric Cheung
#
#                                     articles_content news_org  \
# 0  Metro Manila (CNN Philippines, August 15) – De...      CNN
# 1  (CNN) — On a day his state and others reported...      CNN
# 2  Metro Manila (CNN Philippines, December 6) -- ...      CNN
# 3  (CNN) — Being vaccinated against Covid-19 is m...      CNN
# 4  (CNN) -- Ghana has become the first country to...      CNN
#
#       published_dates
# 0 2020-08-15 00:30:00
# 1 2020-11-17 08:04:00
# 2 2020-12-06 19:06:00
# 3 2020-12-22 08:02:00
# 4 2021-02-25 04:10:00

# %% [markdown]
# ## Philippine News Agency (Justine)

# %%
# # TODO
df_pna = pd.read_csv('datasets/Philippine News Agency Scraped Articles.csv',index_col = 0)
df_pna['published_dates'] = pd.to_datetime(df_pna['published_date'])
df_pna = df_pna.drop(columns = 'published_date')
df_pna = df_pna.rename(columns = {'url':'urls'})
df_pna.info()
df_pna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172 entries, 0 to 171
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   urls              172 non-null    object
#  1   titles            172 non-null    object
#  2   authors           172 non-null    object
#  3   articles_content  172 non-null    object
#  4   news_org          172 non-null    object
#  5   published_dates   172 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 9.4+ KB
#                                         urls  \
# 0    https://www.pna.gov.ph/articles/1133350
# 1    https://www.pna.gov.ph/articles/1133183
# 2    https://www.pna.gov.ph/articles/1133300
# 3    https://www.pna.gov.ph/articles/1133279
# 4    https://www.pna.gov.ph/articles/1133269
# ..                                       ...
# 167  https://www.pna.gov.ph/articles/1132312
# 168  https://www.pna.gov.ph/articles/1132297
# 169  https://www.pna.gov.ph/articles/1132300
# 170  https://www.pna.gov.ph/articles/1132314
# 171  https://www.pna.gov.ph/articles/1132277
#
#                                                 titles  \
# 0    Bong Go wants to be president: PRRD\nBy Ruth A...
# 1    No jab simulation, no vax allocation: DOH-Bico...
# 2    More San Juan front-liners receive jabs\nBy La...
# 3    Guv willing to get P1-B loan to get vax for 2....
# 4    Over 9K AFP front-liners get Covid-19 jabs: Lo...
# ..                                                 ...
# 167  Only mild effects of Covid-19 jab on 2 cops: P...
# 168  'Covid-19 vax is our hope': Pasig doc\nBy Pria...
# 169  House leader to file P50-B supplemental budget...
# 170  QC vaccine rollout for health workers starts W...
# 171  Troops urged to muster strong support for Covi...
#
#                             authors  \
# 0            Ruth Abbey Gita-Carlos
# 1    Connie Calipay and Mar Serrano
# 2                Lade Jean Kabagani
# 3                   Belinda Otordoz
# 4                  Priam Nepomuceno
# ..                              ...
# 167       Christopher Lloyd Caliwan
# 168                Priam Nepomuceno
# 169          Filane Mikee Cervantes
# 170                    Marita Moaje
# 171                Priam Nepomuceno
#
#                                       articles_content  \
# 0    Senator Christopher “Bong” Go and President Ro...
# 1    MORE VACCINES FOR BICOL. The Bicol region rece...
# 2    ASTRAZENECA SHOTS. Healthcare workers in San J...
# 3    CEREMONIAL VACCINATION. Quezon Governor Danilo...
# 4    Defense Secretary Delfin Lorenzana (Screengrab...
# ..                                                 ...
# 167  (PNA photo by Lloyd Caliwan)\nMANILA – Two med...
# 168  GLIMPSE OF HOPE. Dr. Nerissa Sabarre, head of ...
# 169  ACT-CIS Rep. Eric Yap \nMANILA – The chairman ...
# 170  Quezon City Mayor Joy Belmonte  (PNA file phot...
# 171  VACCINE FOR TROOPS. Defense Secretary Delfin L...
#
#                     news_org     published_dates
# 0    Philippines News Agency 2021-03-11 19:21:00
# 1    Philippines News Agency 2021-03-11 18:54:00
# 2    Philippines News Agency 2021-03-11 17:29:00
# 3    Philippines News Agency 2021-03-11 16:27:00
# 4    Philippines News Agency 2021-03-11 14:13:00
# ..                       ...                 ...
# 167  Philippines News Agency 2021-03-02 17:22:00
# 168  Philippines News Agency 2021-03-02 17:14:00
# 169  Philippines News Agency 2021-03-02 17:05:00
# 170  Philippines News Agency 2021-03-02 17:04:00
# 171  Philippines News Agency 2021-03-02 17:04:00
#
# [172 rows x 6 columns]

# %% [markdown]
# # COMBINED DATASET

# %%
df = df_rappler.append(df_gma, ignore_index=True).\
                append(df_cnn, ignore_index=True).\
                append(df_abscbn, ignore_index=True).\
                append(df_sunstar, ignore_index=True).\
                append(df_philstar, ignore_index=True).\
                append(df_pna, ignore_index=True)
#     append(df_manilabulletin, ignore_index=True).\
#     append(df_themanilatimes, ignore_index=True).
   
#     append(df_inquirer, ignore_index=True).\
    
#     

# df['published_dates'] = pd.to_datetime(df['published_dates'])

df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1909 entries, 0 to 1908
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   urls              1909 non-null   object
#  1   titles            1909 non-null   object
#  2   authors           1909 non-null   object
#  3   published_dates   1909 non-null   datetime64[ns]
#  4   articles_content  1670 non-null   object
#  5   news_org          1909 non-null   object
#  6   article_contents  239 non-null    object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 104.5+ KB
#                                                    urls  \
# 0     https://www.rappler.com/newsbreak/explainers/w...
# 1     https://www.rappler.com/newsbreak/iq/timeline-...
# 2     https://www.rappler.com/nation/philippines-rec...
# 3     https://www.rappler.com/nation/philippines-gra...
# 4     https://www.rappler.com/nation/philippines-rec...
# ...                                                 ...
# 1904            https://www.pna.gov.ph/articles/1132312
# 1905            https://www.pna.gov.ph/articles/1132297
# 1906            https://www.pna.gov.ph/articles/1132300
# 1907            https://www.pna.gov.ph/articles/1132314
# 1908            https://www.pna.gov.ph/articles/1132277
#
#                                                  titles  \
# 0     Here’s why COVID-19 vaccines haven’t arrived i...
# 1     TIMELINE: The Philippines’ 2021 COVID-19 vacci...
# 2     After initial delay, Philippines to receive As...
# 3     Philippines grants emergency approval for Sino...
# 4     Philippines receives first COVID-19 vaccine de...
# ...                                                 ...
# 1904  Only mild effects of Covid-19 jab on 2 cops: P...
# 1905  'Covid-19 vax is our hope': Pasig doc\nBy Pria...
# 1906  House leader to file P50-B supplemental budget...
# 1907  QC vaccine rollout for health workers starts W...
# 1908  Troops urged to muster strong support for Covi...
#
#                         authors     published_dates  \
# 0                SOFIA TOMACRUZ 2021-02-18 09:22:00
# 1                SOFIA TOMACRUZ 2021-02-04 19:43:00
# 2                SOFIA TOMACRUZ 2021-03-03 14:41:00
# 3                SOFIA TOMACRUZ 2021-02-22 12:19:00
# 4                SOFIA TOMACRUZ 2021-02-28 16:16:00
# ...                         ...                 ...
# 1904  Christopher Lloyd Caliwan 2021-03-02 17:22:00
# 1905           Priam Nepomuceno 2021-03-02 17:14:00
# 1906     Filane Mikee Cervantes 2021-03-02 17:05:00
# 1907               Marita Moaje 2021-03-02 17:04:00
# 1908           Priam Nepomuceno 2021-03-02 17:04:00
#
#                                        articles_content  \
# 0     MANILA, PHILIPPINES\r\nThe Philippine governme...
# 1     MANILA, PHILIPPINES\r\n(UPDATED) On March 1, t...
# 2     MANILA, PHILIPPINES\r\n(UPDATED) Malacañang sa...
# 3     MANILA, PHILIPPINES\r\n(UPDATED) Its lower eff...
# 4     MANILA, PHILIPPINES\r\n(3rd UPDATE) The arriva...
# ...                                                 ...
# 1904  (PNA photo by Lloyd Caliwan)\nMANILA – Two med...
# 1905  GLIMPSE OF HOPE. Dr. Nerissa Sabarre, head of ...
# 1906  ACT-CIS Rep. Eric Yap \nMANILA – The chairman ...
# 1907  Quezon City Mayor Joy Belmonte  (PNA file phot...
# 1908  VACCINE FOR TROOPS. Defense Secretary Delfin L...
#
#                      news_org article_contents
# 0                     Rappler              NaN
# 1                     Rappler              NaN
# 2                     Rappler              NaN
# 3                     Rappler              NaN
# 4                     Rappler              NaN
# ...                       ...              ...
# 1904  Philippines News Agency              NaN
# 1905  Philippines News Agency              NaN
# 1906  Philippines News Agency              NaN
# 1907  Philippines News Agency              NaN
# 1908  Philippines News Agency              NaN
#
# [1909 rows x 7 columns]

# %% [markdown]
# # CLEANED DATASET

# %%
# TODO

# %% [markdown]
# # SAVE DATASET AS CSV

# %%
FILENAME = 'datasets/combined_and_cleaned.csv'

### Save the dataset as CSV
df.to_csv(FILENAME, index=False)

### Read the CSV dataset
df = pd.read_csv(FILENAME)
# df['published_dates'] = pd.to_datetime(df['published_dates'])
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   urls              1498 non-null   object
#  1   titles            1498 non-null   object
#  2   authors           1498 non-null   object
#  3   published_dates   1498 non-null   object
#  4   articles_content  1498 non-null   object
#  5   news_org          1498 non-null   object
# dtypes: object(6)
# memory usage: 70.3+ KB
#                                                    urls  \
# 0     https://www.rappler.com/newsbreak/explainers/w...
# 1     https://www.rappler.com/newsbreak/iq/timeline-...
# 2     https://www.rappler.com/nation/philippines-rec...
# 3     https://www.rappler.com/nation/philippines-gra...
# 4     https://www.rappler.com/nation/philippines-rec...
# ...                                                 ...
# 1493  https://www.sunstar.com.ph/article/1884896/Zam...
# 1494  https://www.sunstar.com.ph/article/1746415/Zam...
# 1495         https://www.sunstar.com.ph/article/1742363
# 1496  https://www.sunstar.com.ph/article/1815861/Zam...
# 1497  https://www.sunstar.com.ph/article/1769958/Zam...
#
#                                                  titles         authors  \
# 0     Here’s why COVID-19 vaccines haven’t arrived i...  SOFIA TOMACRUZ
# 1     TIMELINE: The Philippines’ 2021 COVID-19 vacci...  SOFIA TOMACRUZ
# 2     After initial delay, Philippines to receive As...  SOFIA TOMACRUZ
# 3     Philippines grants emergency approval for Sino...  SOFIA TOMACRUZ
# 4     Philippines receives first COVID-19 vaccine de...  SOFIA TOMACRUZ
# ...                                                 ...             ...
# 1493          Review on blended modular learning sought         sunstar
# 1494        Illegal ports proliferate in Zamboanga City         sunstar
# 1495  Zamboanga athletes win medals in swimming, wei...     BONG GARCIA
# 1496          Zamboanga weightlifters harvest 48 medals     BONG GARCIA
# 1497       Zamboanga Valientes readies for Oct. 27 game     BONG GARCIA
#
#           published_dates                                   articles_content  \
# 0     2021-02-18 09:22:00  MANILA, PHILIPPINES\r\nThe Philippine governme...
# 1     2021-02-04 19:43:00  MANILA, PHILIPPINES\r\n(UPDATED) On March 1, t...
# 2     2021-03-03 14:41:00  MANILA, PHILIPPINES\r\n(UPDATED) Malacañang sa...
# 3     2021-02-22 12:19:00  MANILA, PHILIPPINES\r\n(UPDATED) Its lower eff...
# 4     2021-02-28 16:16:00  MANILA, PHILIPPINES\r\n(3rd UPDATE) The arriva...
# ...                   ...                                                ...
# 1493  2021-02-04 00:00:00  ZAMBOANGA City Maria Isabelle Climaco-Salazar ...
# 1494  2018-06-04 00:00:00  ZAMBOANGA City Mayor Maria Isabelle Climaco-Sa...
# 1495  2018-05-09 00:00:00  ZAMBOANGUEÑO athletes have reaped medals durin...
# 1496  2019-07-25 00:00:00  THE delegation of Zamboanga City to the recent...
# 1497  2018-10-19 00:00:00  PREPARATIONS are underway by the Zamboanga Val...
#
#      news_org
# 0     Rappler
# 1     Rappler
# 2     Rappler
# 3     Rappler
# 4     Rappler
# ...       ...
# 1493  sunstar
# 1494  sunstar
# 1495  sunstar
# 1496  sunstar
# 1497  sunstar
#
# [1498 rows x 6 columns]
